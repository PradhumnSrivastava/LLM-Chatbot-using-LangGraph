# %%
#LLM testing
from llm.huggingface import llm
llm.invoke("Hello, My Name is Pradhumn.")

# %%
#State Testing
from graph.state import State
print(State)
# Out:
# <class 'graph.state.State'>

# %%
from llm.huggingface import llm
llm.invoke("jai shri ram")
# Out:
# '"Jai Shri Ram" is a phrase in Hindi that expresses devotion and reverence to Lord Rama, a revered figure in Hinduism. It can be translated as "Victory to Lord Rama" or "Glory to Lord Rama." If you have any questions about this phrase or Lord Rama, feel free to ask!'

# %%
from graph.graph_builder import workflow
workflow.invoke({'message':"write 5 line sentence on black holes"})
# result = workflow.invoke({
#     "message": "Write 5 lines about black holes"
# })
# Out:
# {'message': 'write 5 line sentence on black holes',
#  'response': 'Black holes are cosmic phenomena where gravity pulls so much that not even light can escape, forming an event horizon.'}
